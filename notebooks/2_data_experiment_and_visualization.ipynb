# %% [markdown]
# ## Data Exploration

# %%
# import library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set() # Revert to matplotlib defaults
plt.rcParams['figure.figsize'] = (16, 12)

# %%
# load dataset
cleaned_df= pd.read_csv('../datasets/cleaned/solar_irradiation.csv')
cleaned_df.head()
# Out:
#    Unnamed: 0  MonthPE        Date  Daily_Temp  Daily_Precip  Daily_Humidity  \
# 0  2018-12-31       12  2018-12-31   21.333333      8.208333       40.166667
# 1  2019-01-01        1  2019-01-01   22.683333      8.966667       35.916667
# 2  2019-01-02        1  2019-01-02   23.400000     10.466667       38.500000
# 3  2019-01-03        1  2019-01-03   23.775000     13.091667       39.583333
# 4  2019-01-04        1  2019-01-04   24.216667     13.433333       42.333333
#
#    Daily_Pressure  Daily_WindDir  Daily_WindSpeed   Daily_DNI   Daily_DHI  \
# 0      956.008333      93.166667         3.016667  435.000000  145.416667
# 1      955.850000     140.250000         2.325000  619.833333  100.666667
# 2      955.583333     163.083333         1.550000  609.833333  100.000000
# 3      956.275000     170.666667         1.516667  586.166667  107.666667
# 4      955.191667     137.833333         2.116667  581.750000  111.250000
#
#    Daily_radiation
# 0       412.000000
# 1       455.083333
# 2       453.500000
# 3       448.083333
# 4       447.750000

# %%
# Descriptive statistics summary
cleaned_df.describe()
# Out:
#            MonthPE   Daily_Temp  Daily_Precip  Daily_Humidity  Daily_Pressure  \
# count  1098.000000  1098.000000   1098.000000     1098.000000     1098.000000
# mean      6.521858    26.824993     33.394949       54.398192      938.123318
# std       3.455404     3.190834     14.834248       20.582690        6.089265
# min       1.000000    17.783333      4.166667       11.384615      923.623077
# 25%       4.000000    24.660417     20.085577       38.000000      933.967857
# 50%       7.000000    26.008333     31.550000       53.416667      937.296429
# 75%      10.000000    28.435417     47.670238       72.351190      940.016667
# max      12.000000    36.364286     60.630769       95.230769      956.275000
#
#        Daily_WindDir  Daily_WindSpeed    Daily_DNI    Daily_DHI  \
# count    1098.000000      1098.000000  1098.000000  1098.000000
# mean      198.212507         3.457360   271.142463   179.405031
# std        77.335261         1.572916   213.023693    54.543634
# min        38.857143         0.741667     0.000000    19.714286
# 25%       119.604167         2.291667    61.937500   138.223214
# 50%       215.928571         3.134524   257.386905   182.335165
# 75%       265.062500         4.405357   466.062500   218.714286
# max       331.384615        11.264286   748.583333   325.571429
#
#        Daily_radiation
# count      1098.000000
# mean        370.826100
# std         139.137653
# min          19.714286
# 25%         277.678571
# 50%         397.232143
# 75%         480.737637
# max         603.846154

# %%
# check the missing values
cleaned_df.isnull().sum()
# Out:
# Unnamed: 0         0
# MonthPE            0
# Date               0
# Daily_Temp         0
# Daily_Precip       0
# Daily_Humidity     0
# Daily_Pressure     0
# Daily_WindDir      0
# Daily_WindSpeed    0
# Daily_DNI          0
# Daily_DHI          0
# Daily_radiation    0
# dtype: int64

# %%
# summary of dataframe
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1098 entries, 0 to 1097
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1098 non-null   object
#  1   MonthPE          1098 non-null   int64
#  2   Date             1098 non-null   object
#  3   Daily_Temp       1098 non-null   float64
#  4   Daily_Precip     1098 non-null   float64
#  5   Daily_Humidity   1098 non-null   float64
#  6   Daily_Pressure   1098 non-null   float64
#  7   Daily_WindDir    1098 non-null   float64
#  8   Daily_WindSpeed  1098 non-null   float64
#  9   Daily_DNI        1098 non-null   float64
#  10  Daily_DHI        1098 non-null   float64
#  11  Daily_radiation  1098 non-null   float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 103.1+ KB

# %%
# A plot pf total irriadtion for each 
rad_vs_month= cleaned_df.loc[:, ['Daily_radiation', 'MonthPE']].groupby('MonthPE').sum()
rad_vs_month.plot()
plt.xticks(cleaned_df['MonthPE'], rotation=30)
plt.title('Monthly total solar irradiation')
plt.show()

# %%
# Daily solar irradiation plot
f, ax = plt.subplots(figsize=(20, 5))
sns.lineplot(data = cleaned_df, x = "Date", y = "Daily_radiation")

rad_avg= cleaned_df['Daily_radiation'].mean()
ax.axhline(rad_avg, color='green', linestyle='--', label=f"Mean - {rad_avg:.2f}")

ax.set_axisbelow(True)
ax.minorticks_on()
ax.grid(which='major', linestyle='-', linewidth=0.5, color='white',)
ax.grid(which='minor', linestyle=':', linewidth=0.5, color='white', alpha=0.7)

plt.show()
ax.legend()
# Out:
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 6034 ticks ([-54.800000000000004, ..., 1151.8000000000172]), which exceeds Locator.MAXTICKS (1000).

# %%
# Histogram distribution of weather features and solar irradiation
f, ax = plt.subplots(1, 4, figsize=(20,4))
sns.histplot(cleaned_df['Daily_radiation'], stat="density", bins=30, ax=ax[0])
sns.histplot(cleaned_df['Daily_Pressure'], stat="density", bins=30, ax=ax[1])
sns.histplot(cleaned_df['Daily_Humidity'], stat="density", bins=30, ax=ax[2])
sns.histplot(cleaned_df['Daily_Temp'], stat="density", bins=30, ax=ax[3])
plt.show()

# %%
# Histogram plot of daily mean radiation
fig, ax = plt.subplots(figsize=(15, 6))
sns.barplot(x="MonthPE", y='Daily_radiation', data= cleaned_df, palette= "BuPu")
ax.set_title('Daily Mean Radiation')
plt.show()

# %%
# feature correlation
corr= cleaned_df.corr(method = "pearson")

sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap="coolwarm", square=True, annot=True, fmt=".2f")
plt.show()
# Out:
# d:\Omdena\mlops-course\Assignments\Assignment-3\fast-heroku\venv\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Statistical check: stationary or non-stationary

# %%
# Adfuller testt on target feature
from statsmodels.tsa.stattools import adfuller
Xrad = cleaned_df['Daily_radiation'].values
result = adfuller(Xrad)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value)) # p-value <= 0.05
# Out:
# ADF Statistic: -3.734147
# p-value: 0.003658
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568
